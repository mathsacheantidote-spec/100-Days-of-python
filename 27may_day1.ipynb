# %% [markdown]
# <a href="https://colab.research.google.com/github/mathsacheantidote-spec/100-Days-of-python/blob/main/27may_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#a = 34j+78
"""hi
there"""
#print(type(a))
b= True
#print(type(b))
c = "A"
#print(ord(c))
"""a =65#unicode to character conversion
print(chr(a))"""
#string indexing is a way to access any index character in a string
"""R = "Shashank Dixit"
print(R[-1])
#string slicing is a way to separate out some part of string
print(R[0:8:2])
print(R[8::1])"""
# type conversion is a way to convert data types like string, complex , int,
# float , bool in each other.
"""print(type(R))
R= int(R)
print(type(R))"""
# These values of type conversion from int to float must be ints or floats only not strings ValueError: invalid literal for int() with base 10: 'Shashank Dixit'
"""a = 12.3
print(type(a))
a = int(a)
print(type(a))
print(a)"""
"""a= 12
print(bool(a))
a=0
print(bool(a))
there are 7 falsy values 0 , "", false, []empty list, empty tuple(), empty dictionary{}"""
"""implicit and explicit type conversion i.e either we do or by default done
by the built-in functions example: type conversion and division's output as float value"""

"""both output and terminals gives output but we use terminal because we want to have some users input tooo and we
use print function for output like following is few methods for simultaneous output: """
"""a = 98
R = "Shashank Dixit"
print(a,R)
#formatted and unformatted string
age = 98
name = "Shashank Dixit"
print("My name is ", name ," and my age is ", age)
#here multiple strings are created above for which now  we will use formatted string f to get rid of this approach
print(f"My name is {name} and i am {age} years old")"""


"""#Input statements
input("What is your name")#just input taken and stored as garbage value
name = input("What is your name")#stored value in a variable
print(name)
a = input("Enter a number : ")
print(a)
b= input("Enter your name : ")
print(b)"""

"""operators : (BODMAS is followed in python) 1. arithmetic operator are 7 operators +_*/ % // **
2. Assignment operator : =
3. Compound assignment operator : +=, -=, *=, /=, etc
4. comparision operator : either gives true or false as output : ==, !=....etc
5. Logical operator :   """
a = 20
b = 3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
a = 20
b = 3
a+=b
print(a)
a-=b
print(a)
a*=b
print(a)
a/=b
print(a)
a//=b
print(a)
a%=b
print(a)
a**=b
print(a)
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# 23
# 17
# 60
# 6.666666666666667
# 6
# 2
# 8000
# 23
# 20
# 60
# 20.0
# 6.0
# 0.0
# 0.0
# False
# True
# False
# True
# False
# True
